# %% [markdown]
# # Homework 5: Networks and Congress
#
# *Due Friday, November 15, 11:59pm*
#
# <img src="http://img.washingtonpost.com/rf/image_1024w/2010-2019/WashingtonPost/2011/08/05/National-Politics/Images/uscap.JPG">
#
# <br>

# %%
# %matplotlib inline

import json

import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecessary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %% [markdown]
# The website [govtrack.us](http://www.govetrack.us) collects data on activities in the Senate and House of Representatives. It's a great source of information for making data-driven assessments about Congress.

# %% [markdown]
# ### Problem 1.
#
# The directories at http://www.govtrack.us/data/congress/113/votes/2013 contain JSON information about every vote cast for the current (113th)  Congress. Subdirectories beginning with "S" correspond to Senate votes, while subdirectories beginning with "H" correspond to House votes.
#
# Write two functions: one that downloads and parses a single Senate vote page given the vote number, and another that repeatedly calls this function to build a full collection of Senate votes from the 113th Congress.

# %%
"""
Function
--------
get_senate_vote

Scrapes a single JSON page for a particular Senate vote, given by the vote number

Parameters
----------
vote : int
   The vote number to fetch
   
Returns
-------
vote : dict
   The JSON-decoded dictionary for that vote
   
Examples
--------
>>> get_senate_vote(11)['bill']
{u'congress': 113,
 u'number': 325,
 u'title': u'A bill to ensure the complete and timely payment of the obligations of the United States Government until May 19, 2013, and for other purposes.',
 u'type': u'hr'}
"""
#your code here
def get_senate_vote(vote):
    url_base = 'http://www.govtrack.us/data/congress/113/votes/2013/'
    url = url_base + 's' + str(vote) + '/data.json'
    return requests.get(url).json()

# %%
"""
Function
--------
get_all_votes

Scrapes all the Senate votes from http://www.govtrack.us/data/congress/113/votes/2013,
and returns a list of dicts

Parameters
-----------
None

Returns
--------
votes : list of dicts
    List of JSON-parsed dicts for each senate vote
"""
#Your code here
import re
def get_all_votes():
    votes = []
    url = 'http://www.govtrack.us/data/congress/113/votes/2013'
    reg = requests.get(url)
    elements = web.Element(req.text).by_tag('a')
    for e in elements:
        match = re.match('s(\d+)', e.content)
        if match:
            votes.append(get_senate_vote(int(match.group(1))))
    return votes

# %%
vote_data = get_all_votes()

# %%
len(vote_data)
# Out:
# 291

# %% [markdown]
# ### Problem 2
#
# Now, turn these data into a NetworkX graph, according to the spec below. For details on using NetworkX, consult the lab materials for November 1, as well as the [NetworkX documentation](http://networkx.github.io/).

# %%
names = set()
for v in vote_data:
    for k in v['votes'].keys():
        for p in v['votes'][k]:
            names.add(p['display_name'])

len(names)
# Out:
# 104

# %%
weight = {n1: {n2: 0 for n2 in names if n1 != n2} for n1 in names}

# %%
for v in vote_data:
    for k in ('Yea', 'Nay'):
        for p in v['votes'][k]:
            for q in v['votes'][k]:
                if p['display_name']!=q['display_name']:
                    weight[p['display_name']][q['display_name']] += 1

# %%
for n1 in weight.keys():
    for n2 in weight[n1].keys():
        if weight[n1][n2] != 0:
            g.add_edge(n1, n2)
            g[n1][n2]['weight'] = weight[n1][n2]
            g[n1][n2]['difference'] = 1./g[n1][n2]['weight']

# %%
g['Lee (R-UT)']['Baldwin (D-WI)']
# Out:
# {'difference': 0.017543859649122806, 'weight': 57}

# %%
"""
Function
--------
vote_graph

Parameters
----------
data : list of dicts
    The vote database returned from get_vote_data

Returns
-------
graph : NetworkX Graph object, with the following properties
    1. Each node in the graph is labeled using the `display_name` of a Senator (e.g., 'Lee (R-UT)')
    2. Each node has a `color` attribute set to 'r' for Republicans, 
       'b' for Democrats, and 'k' for Independent/other parties.
    3. The edges between two nodes are weighted by the number of 
       times two senators have cast the same Yea or Nay vote
    4. Each edge also has a `difference` attribute, which is set to `1 / weight`.

Examples
--------
>>> graph = vote_graph(vote_data)
>>> graph.node['Lee (R-UT)']
{'color': 'r'}  # attributes for this senator
>>> len(graph['Lee (R-UT)']) # connections to other senators
101
>>> graph['Lee (R-UT)']['Baldwin (D-WI)']  # edge relationship between Lee and Baldwin
{'difference': 0.02, 'weight': 50}
"""
#Your code herei
def vote_graph(data):
    # set up all nodes
    names = set()
    for v in data:
        for p in v['votes'].values()[0]:
            names.add(p['display_name'])
    g = nx.Graph()
    
    for n in list(names):
        g.add_node(n)
        m = re.search('([R|D|I])-', n)
        if m:
            if m.group(1) == 'R':
                g.node[n]['color'] = 'r'
            if m.group(1) == 'D':
                g.node[n]['color'] = 'b'
            if m.group(1) == 'I':
                g.node[n]['color'] = 'k'
    # loop through all the votes to set up edge
    weight = {n1: {n2: 0 for n2 in names if n1 != n2} for n1 in names}
    for v in data:
        for k in ('Yea', 'Nay'):
            for p in v['votes'][k]:
                for q in v['votes'][k]:
                    if p['display_name']!=q['display_name']:
                        weight[p['display_name']][q['display_name']] += 1            
   
    # graph edge has no direction, so doesn't need to have both weight[n1][n2] and weight[n2][n1]
    for n1 in weight.keys():
        for n2 in weight[n1].keys():
            if weight[n1][n2] != 0:
                g.add_edge(n1, n2)
                g[n1][n2]['weight'] = weight[n1][n2]
                g[n1][n2]['difference'] = 1./g[n1][n2]['weight']


    return g

# %%
votes['Baldwin (D-WI)']['Lee (R-UT)']
# Out:
# {'difference': 0.017543859649122806, 'weight': 57}

# %%
votes = vote_graph(vote_data)

# %% [markdown]
# ### How (and how not) to visualize networks
#
# Network plots often *look* impressive, but creating sensible network plots is tricky. From Ben Fry, the author of the Processing program:
# <blockquote>
# Usually a graph layout isn’t the best option for data sets larger than a few dozen nodes. You’re most likely to wind up with enormous spider webs or balls of string, and the mess seen so far is more often the case than not. Graphs can be a powerful way to represent relationships between data, but they are also a very abstract concept, which means that they run the danger of meaning something only to the creator of the graph. Often, simply showing the structure of the data says very little about what it actually means, even though it’s a perfectly accurate means of representing the data. Everything looks like a graph, but almost nothing should ever be drawn as one.
# </blockquote>
#
# Let's look at bad and better ways of visualizing the senate vote network.
#
# First, consider the "default" plot from networkx.

# %%
#this makes sure draw_spring results are the same at each call
np.random.seed(1)  

color = [votes.node[senator]['color'] for senator in votes.nodes()]

#determine position of each node using a spring layout
pos = nx.spring_layout(votes, iterations=200)

#plot the edges
nx.draw_networkx_edges(votes, pos, alpha = .05)

#plot the nodes
nx.draw_networkx_nodes(votes, pos, node_color=color)

#draw the labels
lbls = nx.draw_networkx_labels(votes, pos, alpha=5, font_size=8)

#coordinate information is meaningless here, so let's remove it
plt.xticks([])
plt.yticks([])
remove_border(left=False, bottom=False)

# %% [markdown]
# The spring layout tries to group nodes with large edge-weights near to each other. In this context, that means it tries to organize the Senate into similarly-voting cliques. However, there's simply too much going on in this plot -- we should simplify the representation.

# %% [markdown]
# ### Problem 3
#
# Compute the `Minimum Spanning Tree` of this graph, using the `difference` edge attribute as the weight to minimize. A [Minimum Spanning Tree](http://en.wikipedia.org/wiki/Minimum_spanning_tree) is the subset of edges which trace at least one path through all nodes ("spanning"), with minimum total edge weight. You can think of it as a simplification of a network.
#
# Plot this new network, making modifications as necessary to prevent the graph from becoming too busy.

# %%
len(list(votes.nodes()))
# Out:
# 104

# %%
#Your code here
plt.figure(figsize=(15, 10))
np.random.seed(5)
weight = 'difference'
minTree = nx.minimum_spanning_tree(votes, weight)
minEdge = list(nx.minimum_spanning_edges(votes, weight))
np.random.seed(1)  

color = [votes.node[senator]['color'] for senator in votes.nodes()]

#determine position of each node using a spring layout
pos = nx.spring_layout(minTree, k = 0.008, weight = weight, iterations=900)

#plot the edges
nx.draw_networkx_edges(votes, pos, edgelist = minEdge, alpha = .5, color='r')

#plot the nodes
nx.draw_networkx_nodes(votes, pos, node_color=color, node_size=60)

#draw the labels
lbls = nx.draw_networkx_labels(votes, pos, alpha=5, font_size=8)

#coordinate information is meaningless here, so let's remove it
plt.xticks([])
plt.yticks([])
remove_border(left=False, bottom=False)

# %% [markdown]
# ### Problem 4
#
# While this graph has less information, the remaining information is easier to digest. What does the Minimum Spanning Tree mean in this context? How does this graph relate to partisanship in the Senate? Which nodes in this graph are the most and least bi-partisan?

# %% [markdown]
# *Your answer here*

# %% [markdown]
# ### Problem 5
#
# (For this problem, use the full graph for centrality computation, and not the Minimum Spanning Tree)
#
# Networkx can easily compute [centrality](https://en.wikipedia.org/wiki/Centrality) measurements.
#
# Briefly discuss what ``closeness_centrality`` means, both mathematically and in the context of the present graph -- how does the centrality relate to partisanship? Choose a way to visualize the `closeness_centrality` score for each member of the Senate, using edge `difference` as the distance measurement. Determine the 5 Senators with the highest and lowest centralities.
#
# Comment on your results. In particular, note the outliers John Kerry (who recently resigned his Senate seat when he became Secretary of State), Mo Cowan (Kerry's interim replacement) and Ed Markey (Kerry's permanent replacement) have low centrality scores -- why?

# %% [markdown]
# *Your discussion here*

# %%
#Your code here
import operator
closeness_centrality = nx.closeness_centrality(votes, distance = 'difference')
#cc = [closeness_centrality[p] for p in closeness_centrality.keys()]
cc_sorted = sorted(closeness_centrality.iteritems(), key=operator.itemgetter(1))

# %%
print "the 5 senators with the lowest centralities:"
for (k, v) in cc_sorted[:5]:
    print k, v
# Out:
# the 5 senators with the lowest centralities:
# Kerry (D-MA) 3.96243365083
# Lautenberg (D-NJ) 26.1731143265
# Chiesa (R-NJ) 41.5795648441
# Booker (D-NJ) 44.0662771025
# Markey (D-MA) 64.721637717

# %%
print "the 5 senators with the highest centralities:"
for (k, v) in cc_sorted[-5:]:
    print k, v
# Out:
# the 5 senators with the highest centralities:
# Donnelly (D-IN) 109.468958317
# Murkowski (R-AK) 111.100360195
# Pryor (D-AR) 111.204369285
# Manchin (D-WV) 112.650034408
# Collins (R-ME) 117.854891195

# %%
plt.bar(left = range(len(cc)), height=cc, tick_label = closeness_centrality.keys())
# Out:
# <Container object of 104 artists>

# %% [markdown]
# ### Problem 6
#
# Centrality isn't a perfect proxy for bipartisanship, since it gauges how centralized a node is to the network as a whole, and not how similar a Democrat node is to the Republican sub-network (and vice versa).
#
# Can you come up with another measure that better captures bipartisanship than closeness centrality? Develop your own metric -- how does it differ from the closeness centrality? Use visualizations to support your points.

# %%
other = []
for (n, e) in votes['Alexander (R-TN)'].items():
    if votes.node['Alexander (R-TN)']['color'] != votes.node[n]['color']:
        other.append(e['weight'])
np.mean(other)
# Out:
# 106.0

# %%
votes.node['Alexander (R-TN)']
# Out:
# {'color': 'r'}

# %%
#your code here
def if_other_party(color1, color2):
    if color1 == 'r':
        return color2 == 'b' or color2 == 'k'
    else:
        return color2 == 'r'
    
bp_score = {}
for s in votes:
    bp_score[s] = (np.mean([e['weight'] for (n, e) in votes[s].items() if if_other_party(votes.node[s]['color'], 
                                                                                 votes.node[n]['color']) ]
                        ))
# sort bp_score
sorted_bp_score = sorted(bp_score.iteritems(), key=operator.itemgetter(1))
sorted_bp_score
# Out:
# [(u'Kerry (D-MA)', 2.2352941176470589),
#  (u'Lautenberg (D-NJ)', 9.2888888888888896),
#  (u'Booker (D-NJ)', 10.022222222222222),
#  (u'Markey (D-MA)', 30.369565217391305),
#  (u'Chiesa (R-NJ)', 39.072727272727271),
#  (u'Cowan (D-MA)', 50.391304347826086),
#  (u'Inhofe (R-OK)', 53.517241379310342),
#  (u'Cruz (R-TX)', 55.877192982456137),
#  (u'Risch (R-ID)', 57.051724137931032),
#  (u'Lee (R-UT)', 57.438596491228068),
#  (u'Vitter (R-LA)', 57.672413793103445),
#  (u'Scott (R-SC)', 60.666666666666664),
#  (u'Paul (R-KY)', 61.526315789473685),
#  (u'Coburn (R-OK)', 61.859649122807021),
#  (u'Crapo (R-ID)', 65.465517241379317),
#  (u'Roberts (R-KS)', 65.91379310344827),
#  (u'Enzi (R-WY)', 66.534482758620683),
#  (u'Barrasso (R-WY)', 67.965517241379317),
#  (u'Cornyn (R-TX)', 69.741379310344826),
#  (u'Johnson (R-WI)', 69.912280701754383),
#  (u'Sessions (R-AL)', 70.421052631578945),
#  (u'Rubio (R-FL)', 72.421052631578945),
#  (u'Shelby (R-AL)', 76.41379310344827),
#  (u'McConnell (R-KY)', 77.568965517241381),
#  (u'Moran (R-KS)', 77.706896551724142),
#  (u'Boxer (D-CA)', 79.021739130434781),
#  (u'Grassley (R-IA)', 79.293103448275858),
#  (u'Toomey (R-PA)', 80.879310344827587),
#  (u'Warren (D-MA)', 82.347826086956516),
#  (u'Sanders (I-VT)', 84.086956521739125),
#  (u'Heller (R-NV)', 84.84482758620689),
#  (u'Murray (D-WA)', 85.130434782608702),
#  (u'Rockefeller (D-WV)', 85.130434782608702),
#  (u'Reed (D-RI)', 85.152173913043484),
#  (u'Whitehouse (D-RI)', 85.391304347826093),
#  (u'Brown (D-OH)', 85.739130434782609),
#  (u'Menendez (D-NJ)', 85.934782608695656),
#  (u'Boozman (R-AR)', 86.0),
#  (u'Mikulski (D-MD)', 86.108695652173907),
#  (u'Hirono (D-HI)', 86.217391304347828),
#  (u'Schatz (D-HI)', 86.478260869565219),
#  (u'Coats (R-IN)', 87.0),
#  (u'Murphy (D-CT)', 87.043478260869563),
#  (u'Cantwell (D-WA)', 87.108695652173907),
#  (u'Fischer (R-NE)', 87.431034482758619),
#  (u'Gillibrand (D-NY)', 87.652173913043484),
#  (u'Cardin (D-MD)', 87.652173913043484),
#  (u'Blumenthal (D-CT)', 87.739130434782609),
#  (u'Leahy (D-VT)', 87.847826086956516),
#  (u'Harkin (D-IA)', 87.913043478260875),
#  (u'Schumer (D-NY)', 87.913043478260875),
#  (u'Baldwin (D-WI)', 87.978260869565219),
#  (u'Merkley (D-OR)', 88.543478260869563),
#  (u'Udall (D-NM)', 88.565217391304344),
#  (u'Stabenow (D-MI)', 89.086956521739125),
#  (u'Levin (D-MI)', 89.434782608695656),
#  (u'Durbin (D-IL)', 89.673913043478265),
#  (u'Feinstein (D-CA)', 89.739130434782609),
#  (u'Franken (D-MN)', 90.456521739130437),
#  (u'Thune (R-SD)', 90.551724137931032),
#  (u'Wyden (D-OR)', 90.608695652173907),
#  (u'Johnson (D-SD)', 91.673913043478265),
#  (u'Nelson (D-FL)', 92.065217391304344),
#  (u'Shaheen (D-NH)', 92.739130434782609),
#  (u'Coons (D-DE)', 93.282608695652172),
#  (u'Udall (D-CO)', 93.434782608695656),
#  (u'Casey (D-PA)', 94.108695652173907),
#  (u'Heinrich (D-NM)', 94.173913043478265),
#  (u'Burr (R-NC)', 94.192982456140356),
#  (u'Carper (D-DE)', 95.304347826086953),
#  (u'Klobuchar (D-MN)', 95.391304347826093),
#  (u'Blunt (R-MO)', 95.810344827586206),
#  (u'Johanns (R-NE)', 96.379310344827587),
#  (u'Reid (D-NV)', 96.717391304347828),
#  (u'Bennet (D-CO)', 96.847826086956516),
#  (u'Kaine (D-VA)', 98.130434782608702),
#  (u'Landrieu (D-LA)', 98.413043478260875),
#  (u'Begich (D-AK)', 99.369565217391298),
#  (u'Warner (D-VA)', 99.934782608695656),
#  (u'Hoeven (R-ND)', 100.08620689655173),
#  (u'King (I-ME)', 100.43478260869566),
#  (u'Chambliss (R-GA)', 100.63157894736842),
#  (u'Tester (D-MT)', 102.39130434782609),
#  (u'Heitkamp (D-ND)', 102.56521739130434),
#  (u'McCaskill (D-MO)', 104.1304347826087),
#  (u'Cochran (R-MS)', 104.91379310344827),
#  (u'Isakson (R-GA)', 104.96551724137932),
#  (u'Wicker (R-MS)', 105.17241379310344),
#  (u'Alexander (R-TN)', 106.0),
#  (u'Baucus (D-MT)', 106.32608695652173),
#  (u'Flake (R-AZ)', 107.01724137931035),
#  (u'Portman (R-OH)', 109.03448275862068),
#  (u'Hatch (R-UT)', 109.20689655172414),
#  (u'Ayotte (R-NH)', 110.29310344827586),
#  (u'Graham (R-SC)', 110.70689655172414),
#  (u'Corker (R-TN)', 112.75862068965517),
#  (u'Kirk (R-IL)', 114.75862068965517),
#  (u'Hagan (D-NC)', 115.5),
#  (u'Donnelly (D-IN)', 116.52173913043478),
#  (u'McCain (R-AZ)', 117.60344827586206),
#  (u'Pryor (D-AR)', 123.60869565217391),
#  (u'Manchin (D-WV)', 132.84782608695653),
#  (u'Murkowski (R-AK)', 162.31034482758622),
#  (u'Collins (R-ME)', 185.32758620689654)]

# %% [markdown]
# *Your discussion here*

# %% [markdown]
# ## Leadership in the Senate
#
# There are many metrics to quantify the leadership in the Senate.
#
#   1. Senate leaders sponsor and co-sponsor lots of bills
#   2. Leaders sit on many committees, as well as more important committees
#   3. Leaders usually have been in office for a long time
#
# Another approach uses the philosophy behind how Google ranks search results. The core idea behind Google's PageRank algorithm is:
#
# 1. A "good" website (i.e. one to rank highly in search results) is linked to by many other websites
# 2. A link found on a "good" website is more important than a link found on a "bad" website
#
# The PageRank algorithm thus assigns scores to nodes in a graph based on how many neighbors a node has, as well as the score of those neighbors.
#
# This technique can be adapted to rank Senate leadership. Here, nodes correspond to Senators, and edges correspond to a senator co-sponsoring a bill sponsored by another Senator. The weight of each edge from node A to B is the number of times Senator A has co-sponsored a bill whose primary sponsor is Senator B. If you interpret the PageRank scores of such a network to indicate Senate leadership, you are then assuming:
#
# 1. Leaders sponsor more bills
# 1. Leaders attract co-sponsorship from other leaders
#
# ### Problem 7
#
# Govtrack stores information about each Senate bill in the current congress at http://www.govtrack.us/data/congress/113/bills/s/. As in problem 1, write two functions to scrape these data -- the first function downloads a single bill, and the second function calls the first to loop over all bills.

# %%
"""
Function
--------
get_senate_bill

Scrape the bill data from a single JSON page, given the bill number

Parameters
-----------
bill : int
   Bill number to fetch
   
Returns
-------
A dict, parsed from the JSON

Examples
--------
>>> bill = get_senate_bill(10)
>>> bill['sponsor']
{u'district': None,
 u'name': u'Reid, Harry',
 u'state': u'NV',
 u'thomas_id': u'00952',
 u'title': u'Sen',
 u'type': u'person'}
>>> bill['short_title']
u'Agriculture Reform, Food, and Jobs Act of 2013'
"""
#your code here
def get_senate_bill(bill):
    url = "https://www.govtrack.us/data/congress/113/bills/s/s" + str(bill) + "/data.json"
    req = requests.get(url)
    return req.json()

# %%
get_senate_bill(10)['sponsor']
# Out:
# {u'district': None,
#  u'name': u'Reid, Harry',
#  u'state': u'NV',
#  u'thomas_id': u'00952',
#  u'title': u'Sen',
#  u'type': u'person'}

# %%
"""
Function
--------
get_all_bills

Scrape all Senate bills at http://www.govtrack.us/data/congress/113/bills/s

Parameters
----------
None

Returns
-------
A list of dicts, one for each bill
"""
#your code here
import time
def get_all_bills():
    # get html with all links
    bills = []
    req = requests.get("https://www.govtrack.us/data/congress/113/bills/s")
    html = req.text
    element = web.Element(html).by_tag('a')
    # loop through the links
    for e in element:
        match = re.search('s(\d+)', e.content)
        if match:
            bills.append(get_senate_bill(int(match.group(1))))
            time.sleep(0.1)
    return bills

# %%
bill_list = get_all_bills()

# %% [markdown]
# ### Problem 8
#
# Write a function to builded a Directed Graph (DiGraph) from these data, according to the following spec:

# %%
bill_list[0]['cosponsors']
# Out:
# [{u'district': None,
#   u'name': u'Blumenthal, Richard',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'CT',
#   u'thomas_id': u'02076',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Boxer, Barbara',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'CA',
#   u'thomas_id': u'00116',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Brown, Sherrod',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'OH',
#   u'thomas_id': u'00136',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Coons, Christopher A.',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'DE',
#   u'thomas_id': u'01984',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Durbin, Richard',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'IL',
#   u'thomas_id': u'00326',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Feinstein, Dianne',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'CA',
#   u'thomas_id': u'01332',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Gillibrand, Kirsten E.',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'NY',
#   u'thomas_id': u'01866',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Heinrich, Martin',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'NM',
#   u'thomas_id': u'01937',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Hirono, Mazie K.',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'HI',
#   u'thomas_id': u'01844',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Klobuchar, Amy',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'MN',
#   u'thomas_id': u'01826',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Leahy, Patrick J.',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'VT',
#   u'thomas_id': u'01383',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Levin, Carl',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'MI',
#   u'thomas_id': u'01384',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Menendez, Robert',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'NJ',
#   u'thomas_id': u'00791',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Schatz, Brian',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'HI',
#   u'thomas_id': u'02173',
#   u'title': u'Sen',
#   u'withdrawn_at': None},
#  {u'district': None,
#   u'name': u'Schumer, Charles E.',
#   u'sponsored_at': u'2013-01-22',
#   u'state': u'NY',
#   u'thomas_id': u'01036',
#   u'title': u'Sen',
#   u'withdrawn_at': None}]

# %%
senators = set()
for b in bill_list:
    senators.add(b['sponsor']['name'])
    for s in b['cosponsors']:
        senators.add(s['name'])
len(senators)
# Out:
# 105

# %%
d = {'a': 1, 'b': 2}
d['a']
# Out:
# 1

# %%
for s1 in weight:
    for s2 in weight[s1]:
        g.add_edge(s1, s2, {'weight': weight[s1][s2]})
g.edge
# Out:
# {u'Alexander, Lamar': {u'Ayotte, Kelly': {'weight': 1},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 3},
#   u'Baucus, Max': {'weight': 1},
#   u'Begich, Mark': {'weight': 0},
#   u'Bennet, Michael F.': {'weight': 3},
#   u'Blumenthal, Richard': {'weight': 1},
#   u'Blunt, Roy': {'weight': 3},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 1},
#   u'Boxer, Barbara': {'weight': 0},
#   u'Brown, Sherrod': {'weight': 2},
#   u'Burr, Richard': {'weight': 1},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 2},
#   u'Carper, Thomas R.': {'weight': 0},
#   u'Casey, Robert P., Jr.': {'weight': 5},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 1},
#   u'Coburn, Tom': {'weight': 4},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 0},
#   u'Coons, Christopher A.': {'weight': 1},
#   u'Corker, Bob': {'weight': 2},
#   u'Cornyn, John': {'weight': 2},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 2},
#   u'Donnelly, Joe': {'weight': 1},
#   u'Durbin, Richard': {'weight': 0},
#   u'Enzi, Michael B.': {'weight': 3},
#   u'Feinstein, Dianne': {'weight': 0},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 3},
#   u'Franken, Al': {'weight': 0},
#   u'Gillibrand, Kirsten E.': {'weight': 0},
#   u'Graham, Lindsey': {'weight': 2},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 2},
#   u'Harkin, Tom': {'weight': 6},
#   u'Hatch, Orrin G.': {'weight': 6},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 2},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 3},
#   u'Inhofe, James M.': {'weight': 1},
#   u'Isakson, Johnny': {'weight': 2},
#   u'Johanns, Mike': {'weight': 2},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 0},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 1},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 1},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 3},
#   u'Markey, Edward J.': {'weight': 0},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 1},
#   u'Menendez, Robert': {'weight': 1},
#   u'Merkley, Jeff': {'weight': 0},
#   u'Mikulski, Barbara A.': {'weight': 1},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 0},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 2},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 3},
#   u'Pryor, Mark L.': {'weight': 4},
#   u'Reed, Jack': {'weight': 2},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 1},
#   u'Rockefeller, John D., IV': {'weight': 1},
#   u'Rubio, Marco': {'weight': 3},
#   u'Sanders, Bernard': {'weight': 2},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 0},
#   u'Scott, Tim': {'weight': 1},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 1},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 0},
#   u'Tester, Jon': {'weight': 0},
#   u'Thune, John': {'weight': 4},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 1},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 0},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Ayotte, Kelly': {u'Alexander, Lamar': {'weight': 1},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 4},
#   u'Baucus, Max': {'weight': 1},
#   u'Begich, Mark': {'weight': 3},
#   u'Bennet, Michael F.': {'weight': 3},
#   u'Blumenthal, Richard': {'weight': 4},
#   u'Blunt, Roy': {'weight': 8},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 2},
#   u'Boxer, Barbara': {'weight': 3},
#   u'Brown, Sherrod': {'weight': 5},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 1},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 3},
#   u'Casey, Robert P., Jr.': {'weight': 1},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 1},
#   u'Coburn, Tom': {'weight': 6},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 6},
#   u'Coons, Christopher A.': {'weight': 3},
#   u'Corker, Bob': {'weight': 1},
#   u'Cornyn, John': {'weight': 3},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 3},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 0},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 2},
#   u'Fischer, Deb': {'weight': 1},
#   u'Flake, Jeff': {'weight': 2},
#   u'Franken, Al': {'weight': 3},
#   u'Gillibrand, Kirsten E.': {'weight': 0},
#   u'Graham, Lindsey': {'weight': 2},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 3},
#   u'Harkin, Tom': {'weight': 5},
#   u'Hatch, Orrin G.': {'weight': 5},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 4},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 2},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 3},
#   u'Johanns, Mike': {'weight': 2},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 2},
#   u'Klobuchar, Amy': {'weight': 7},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 5},
#   u'Lee, Mike': {'weight': 2},
#   u'Levin, Carl': {'weight': 1},
#   u'Manchin, Joe, III': {'weight': 4},
#   u'Markey, Edward J.': {'weight': 3},
#   u'McCain, John': {'weight': 3},
#   u'McCaskill, Claire': {'weight': 3},
#   u'McConnell, Mitch': {'weight': 1},
#   u'Menendez, Robert': {'weight': 3},
#   u'Merkley, Jeff': {'weight': 1},
#   u'Mikulski, Barbara A.': {'weight': 1},
#   u'Moran, Jerry': {'weight': 3},
#   u'Murkowski, Lisa': {'weight': 0},
#   u'Murphy, Christopher S.': {'weight': 1},
#   u'Murray, Patty': {'weight': 1},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 4},
#   u'Portman, Rob': {'weight': 7},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 3},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 2},
#   u'Roberts, Pat': {'weight': 1},
#   u'Rockefeller, John D., IV': {'weight': 1},
#   u'Rubio, Marco': {'weight': 5},
#   u'Sanders, Bernard': {'weight': 2},
#   u'Schatz, Brian': {'weight': 0},
#   u'Schumer, Charles E.': {'weight': 1},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 14},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 1},
#   u'Tester, Jon': {'weight': 6},
#   u'Thune, John': {'weight': 6},
#   u'Toomey, Pat': {'weight': 2},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 3},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 6},
#   u'Warren, Elizabeth': {'weight': 2},
#   u'Whitehouse, Sheldon': {'weight': 2},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 3}},
#  u'Baldwin, Tammy': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 4},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 3},
#   u'Begich, Mark': {'weight': 1},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 7},
#   u'Blunt, Roy': {'weight': 2},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 4},
#   u'Brown, Sherrod': {'weight': 9},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 1},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 3},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 1},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 3},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 1},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 7},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 1},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 5},
#   u'Gillibrand, Kirsten E.': {'weight': 3},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 3},
#   u'Harkin, Tom': {'weight': 16},
#   u'Hatch, Orrin G.': {'weight': 0},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 2},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 1},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 0},
#   u'Johnson, Ron': {'weight': 2},
#   u'Johnson, Tim': {'weight': 1},
#   u'Kaine, Tim': {'weight': 2},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 0},
#   u'Klobuchar, Amy': {'weight': 7},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 4},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 4},
#   u'Manchin, Joe, III': {'weight': 1},
#   u'Markey, Edward J.': {'weight': 2},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 2},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 2},
#   u'Merkley, Jeff': {'weight': 2},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 2},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 6},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 1},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 8},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 1},
#   u'Rockefeller, John D., IV': {'weight': 4},
#   u'Rubio, Marco': {'weight': 1},
#   u'Sanders, Bernard': {'weight': 7},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 6},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 4},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 4},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 1},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 4},
#   u'Whitehouse, Sheldon': {'weight': 3},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 6}},
#  u'Barrasso, John': {u'Alexander, Lamar': {'weight': 4},
#   u'Ayotte, Kelly': {'weight': 1},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Baucus, Max': {'weight': 1},
#   u'Begich, Mark': {'weight': 0},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 1},
#   u'Blunt, Roy': {'weight': 5},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 1},
#   u'Brown, Sherrod': {'weight': 2},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 0},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 0},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 2},
#   u'Coburn, Tom': {'weight': 6},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 0},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 2},
#   u'Cornyn, John': {'weight': 4},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 2},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 0},
#   u'Enzi, Michael B.': {'weight': 11},
#   u'Feinstein, Dianne': {'weight': 0},
#   u'Fischer, Deb': {'weight': 3},
#   u'Flake, Jeff': {'weight': 3},
#   u'Franken, Al': {'weight': 1},
#   u'Gillibrand, Kirsten E.': {'weight': 0},
#   u'Graham, Lindsey': {'weight': 1},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 2},
#   u'Hatch, Orrin G.': {'weight': 7},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 3},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 7},
#   u'Inhofe, James M.': {'weight': 1},
#   u'Isakson, Johnny': {'weight': 1},
#   u'Johanns, Mike': {'weight': 5},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 2},
#   u'Klobuchar, Amy': {'weight': 2},
#   u'Landrieu, Mary L.': {'weight': 0},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 4},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 3},
#   u'Markey, Edward J.': {'weight': 0},
#   u'McCain, John': {'weight': 3},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 1},
#   u'Menendez, Robert': {'weight': 2},
#   u'Merkley, Jeff': {'weight': 1},
#   u'Mikulski, Barbara A.': {'weight': 0},
#   u'Moran, Jerry': {'weight': 5},
#   u'Murkowski, Lisa': {'weight': 3},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 0},
#   u'Nelson, Bill': {'weight': 0},
#   u'Paul, Rand': {'weight': 4},
#   u'Portman, Rob': {'weight': 6},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 0},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 1},
#   u'Roberts, Pat': {'weight': 7},
#   u'Rockefeller, John D., IV': {'weight': 0},
#   u'Rubio, Marco': {'weight': 4},
#   u'Sanders, Bernard': {'weight': 0},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 0},
#   u'Scott, Tim': {'weight': 1},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 0},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 0},
#   u'Tester, Jon': {'weight': 1},
#   u'Thune, John': {'weight': 6},
#   u'Toomey, Pat': {'weight': 1},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 4},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 0},
#   u'Wicker, Roger F.': {'weight': 1},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Baucus, Max': {u'Alexander, Lamar': {'weight': 0},
#   u'Ayotte, Kelly': {'weight': 0},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 0},
#   u'Begich, Mark': {'weight': 3},
#   u'Bennet, Michael F.': {'weight': 2},
#   u'Blumenthal, Richard': {'weight': 1},
#   u'Blunt, Roy': {'weight': 0},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 3},
#   u'Brown, Sherrod': {'weight': 2},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 1},
#   u'Cardin, Benjamin L.': {'weight': 1},
#   u'Carper, Thomas R.': {'weight': 0},
#   u'Casey, Robert P., Jr.': {'weight': 0},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 1},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 0},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 1},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 1},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 1},
#   u'Franken, Al': {'weight': 1},
#   u'Gillibrand, Kirsten E.': {'weight': 0},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 1},
#   u'Hatch, Orrin G.': {'weight': 0},
#   u'Heinrich, Martin': {'weight': 1},
#   u'Heitkamp, Heidi': {'weight': 1},
#   u'Heller, Dean': {'weight': 1},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 2},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 0},
#   u'Klobuchar, Amy': {'weight': 0},
#   u'Landrieu, Mary L.': {'weight': 0},
#   u'Lautenberg, Frank R.': {'weight': 2},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 0},
#   u'Markey, Edward J.': {'weight': 0},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 0},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 0},
#   u'Merkley, Jeff': {'weight': 3},
#   u'Mikulski, Barbara A.': {'weight': 1},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 0},
#   u'Nelson, Bill': {'weight': 0},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 2},
#   u'Pryor, Mark L.': {'weight': 1},
#   u'Reed, Jack': {'weight': 0},
#   u'Reid, Harry': {'weight': 5},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 0},
#   u'Rubio, Marco': {'weight': 0},
#   u'Sanders, Bernard': {'weight': 1},
#   u'Schatz, Brian': {'weight': 0},
#   u'Schumer, Charles E.': {'weight': 1},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 0},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 0},
#   u'Tester, Jon': {'weight': 19},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 1},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 1},
#   u'Wicker, Roger F.': {'weight': 2},
#   u'Wyden, Ron': {'weight': 1}},
#  u'Begich, Mark': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 4},
#   u'Baldwin, Tammy': {'weight': 1},
#   u'Barrasso, John': {'weight': 2},
#   u'Baucus, Max': {'weight': 2},
#   u'Bennet, Michael F.': {'weight': 3},
#   u'Blumenthal, Richard': {'weight': 9},
#   u'Blunt, Roy': {'weight': 4},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 3},
#   u'Boxer, Barbara': {'weight': 11},
#   u'Brown, Sherrod': {'weight': 9},
#   u'Burr, Richard': {'weight': 2},
#   u'Cantwell, Maria': {'weight': 5},
#   u'Cardin, Benjamin L.': {'weight': 6},
#   u'Carper, Thomas R.': {'weight': 3},
#   u'Casey, Robert P., Jr.': {'weight': 7},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 1},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 4},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 2},
#   u'Cornyn, John': {'weight': 1},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 1},
#   u'Durbin, Richard': {'weight': 5},
#   u'Enzi, Michael B.': {'weight': 1},
#   u'Feinstein, Dianne': {'weight': 3},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 6},
#   u'Gillibrand, Kirsten E.': {'weight': 7},
#   u'Graham, Lindsey': {'weight': 2},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 4},
#   u'Harkin, Tom': {'weight': 10},
#   u'Hatch, Orrin G.': {'weight': 1},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 2},
#   u'Heller, Dean': {'weight': 3},
#   u'Hirono, Mazie K.': {'weight': 6},
#   u'Hoeven, John': {'weight': 5},
#   u'Inhofe, James M.': {'weight': 2},
#   u'Isakson, Johnny': {'weight': 3},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 1},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 1},
#   u'Kirk, Mark Steven': {'weight': 3},
#   u'Klobuchar, Amy': {'weight': 6},
#   u'Landrieu, Mary L.': {'weight': 5},
#   u'Lautenberg, Frank R.': {'weight': 2},
#   u'Leahy, Patrick J.': {'weight': 5},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 2},
#   u'Manchin, Joe, III': {'weight': 3},
#   u'Markey, Edward J.': {'weight': 2},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 8},
#   u'Merkley, Jeff': {'weight': 4},
#   u'Mikulski, Barbara A.': {'weight': 3},
#   u'Moran, Jerry': {'weight': 5},
#   u'Murkowski, Lisa': {'weight': 27},
#   u'Murphy, Christopher S.': {'weight': 2},
#   u'Murray, Patty': {'weight': 8},
#   u'Nelson, Bill': {'weight': 2},
#   u'Paul, Rand': {'weight': 2},
#   u'Portman, Rob': {'weight': 2},
#   u'Pryor, Mark L.': {'weight': 10},
#   u'Reed, Jack': {'weight': 3},
#   u'Reid, Harry': {'weight': 4},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 2},
#   u'Rockefeller, John D., IV': {'weight': 3},
#   u'Rubio, Marco': {'weight': 0},
#   u'Sanders, Bernard': {'weight': 12},
#   u'Schatz, Brian': {'weight': 4},
#   u'Schumer, Charles E.': {'weight': 4},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 10},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 3},
#   u'Tester, Jon': {'weight': 27},
#   u'Thune, John': {'weight': 2},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 10},
#   u'Udall, Tom': {'weight': 2},
#   u'Vitter, David': {'weight': 1},
#   u'Walsh, John E.': {'weight': 2},
#   u'Warner, Mark R.': {'weight': 7},
#   u'Warren, Elizabeth': {'weight': 5},
#   u'Whitehouse, Sheldon': {'weight': 3},
#   u'Wicker, Roger F.': {'weight': 1},
#   u'Wyden, Ron': {'weight': 7}},
#  u'Bennet, Michael F.': {u'Alexander, Lamar': {'weight': 2},
#   u'Ayotte, Kelly': {'weight': 3},
#   u'Baldwin, Tammy': {'weight': 1},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 3},
#   u'Begich, Mark': {'weight': 1},
#   u'Blumenthal, Richard': {'weight': 3},
#   u'Blunt, Roy': {'weight': 0},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 3},
#   u'Brown, Sherrod': {'weight': 6},
#   u'Burr, Richard': {'weight': 2},
#   u'Cantwell, Maria': {'weight': 1},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 4},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 1},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 1},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 1},
#   u'Durbin, Richard': {'weight': 4},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 1},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 1},
#   u'Franken, Al': {'weight': 3},
#   u'Gillibrand, Kirsten E.': {'weight': 1},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 2},
#   u'Harkin, Tom': {'weight': 8},
#   u'Hatch, Orrin G.': {'weight': 2},
#   u'Heinrich, Martin': {'weight': 1},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 1},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 1},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 2},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 3},
#   u'Landrieu, Mary L.': {'weight': 0},
#   u'Lautenberg, Frank R.': {'weight': 1},
#   u'Leahy, Patrick J.': {'weight': 3},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 1},
#   u'Markey, Edward J.': {'weight': 1},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 0},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 5},
#   u'Merkley, Jeff': {'weight': 1},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 1},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 2},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 3},
#   u'Pryor, Mark L.': {'weight': 1},
#   u'Reed, Jack': {'weight': 3},
#   u'Reid, Harry': {'weight': 1},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 0},
#   u'Rubio, Marco': {'weight': 0},
#   u'Sanders, Bernard': {'weight': 1},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 5},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 5},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 0},
#   u'Tester, Jon': {'weight': 5},
#   u'Thune, John': {'weight': 2},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 18},
#   u'Udall, Tom': {'weight': 4},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 1},
#   u'Warner, Mark R.': {'weight': 3},
#   u'Warren, Elizabeth': {'weight': 2},
#   u'Whitehouse, Sheldon': {'weight': 1},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 3}},
#  u'Blumenthal, Richard': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 4},
#   u'Baldwin, Tammy': {'weight': 2},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 4},
#   u'Begich, Mark': {'weight': 7},
#   u'Bennet, Michael F.': {'weight': 1},
#   u'Blunt, Roy': {'weight': 3},
#   u'Booker, Cory A.': {'weight': 1},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 11},
#   u'Brown, Sherrod': {'weight': 9},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 3},
#   u'Cardin, Benjamin L.': {'weight': 4},
#   u'Carper, Thomas R.': {'weight': 0},
#   u'Casey, Robert P., Jr.': {'weight': 9},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 1},
#   u'Coburn, Tom': {'weight': 1},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 3},
#   u'Coons, Christopher A.': {'weight': 2},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 2},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 16},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 8},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 11},
#   u'Gillibrand, Kirsten E.': {'weight': 14},
#   u'Graham, Lindsey': {'weight': 2},
#   u'Grassley, Chuck': {'weight': 2},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 10},
#   u'Hatch, Orrin G.': {'weight': 2},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 1},
#   u'Heller, Dean': {'weight': 2},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 1},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 1},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 0},
#   u'Klobuchar, Amy': {'weight': 8},
#   u'Landrieu, Mary L.': {'weight': 3},
#   u'Lautenberg, Frank R.': {'weight': 13},
#   u'Leahy, Patrick J.': {'weight': 17},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 1},
#   u'Manchin, Joe, III': {'weight': 0},
#   u'Markey, Edward J.': {'weight': 6},
#   u'McCain, John': {'weight': 2},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 14},
#   u'Merkley, Jeff': {'weight': 5},
#   u'Mikulski, Barbara A.': {'weight': 1},
#   u'Moran, Jerry': {'weight': 1},
#   u'Murkowski, Lisa': {'weight': 0},
#   u'Murphy, Christopher S.': {'weight': 9},
#   u'Murray, Patty': {'weight': 6},
#   u'Nelson, Bill': {'weight': 7},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 1},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 6},
#   u'Reid, Harry': {'weight': 6},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 10},
#   u'Rubio, Marco': {'weight': 1},
#   u'Sanders, Bernard': {'weight': 14},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 12},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 7},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 6},
#   u'Tester, Jon': {'weight': 13},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 1},
#   u'Warner, Mark R.': {'weight': 2},
#   u'Warren, Elizabeth': {'weight': 4},
#   u'Whitehouse, Sheldon': {'weight': 6},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 7}},
#  u'Blunt, Roy': {u'Alexander, Lamar': {'weight': 3},
#   u'Ayotte, Kelly': {'weight': 6},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 8},
#   u'Baucus, Max': {'weight': 2},
#   u'Begich, Mark': {'weight': 4},
#   u'Bennet, Michael F.': {'weight': 1},
#   u'Blumenthal, Richard': {'weight': 1},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boozman, John': {'weight': 3},
#   u'Boxer, Barbara': {'weight': 4},
#   u'Brown, Sherrod': {'weight': 9},
#   u'Burr, Richard': {'weight': 1},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 4},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 6},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 4},
#   u'Coburn, Tom': {'weight': 4},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 3},
#   u'Coons, Christopher A.': {'weight': 2},
#   u'Corker, Bob': {'weight': 3},
#   u'Cornyn, John': {'weight': 4},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 3},
#   u'Donnelly, Joe': {'weight': 2},
#   u'Durbin, Richard': {'weight': 2},
#   u'Enzi, Michael B.': {'weight': 4},
#   u'Feinstein, Dianne': {'weight': 1},
#   u'Fischer, Deb': {'weight': 2},
#   u'Flake, Jeff': {'weight': 1},
#   u'Franken, Al': {'weight': 2},
#   u'Gillibrand, Kirsten E.': {'weight': 2},
#   u'Graham, Lindsey': {'weight': 1},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 1},
#   u'Harkin, Tom': {'weight': 6},
#   u'Hatch, Orrin G.': {'weight': 6},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 6},
#   u'Inhofe, James M.': {'weight': 4},
#   u'Isakson, Johnny': {'weight': 2},
#   u'Johanns, Mike': {'weight': 5},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 2},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 1},
#   u'Kirk, Mark Steven': {'weight': 2},
#   u'Klobuchar, Amy': {'weight': 6},
#   u'Landrieu, Mary L.': {'weight': 4},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 4},
#   u'Levin, Carl': {'weight': 1},
#   u'Manchin, Joe, III': {'weight': 5},
#   u'Markey, Edward J.': {'weight': 1},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 9},
#   u'McConnell, Mitch': {'weight': 1},
#   u'Menendez, Robert': {'weight': 4},
#   u'Merkley, Jeff': {'weight': 0},
#   u'Mikulski, Barbara A.': {'weight': 0},
#   u'Moran, Jerry': {'weight': 3},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 2},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 2},
#   u'Portman, Rob': {'weight': 7},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 2},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 1},
#   u'Roberts, Pat': {'weight': 4},
#   u'Rockefeller, John D., IV': {'weight': 3},
#   u'Rubio, Marco': {'weight': 8},
#   u'Sanders, Bernard': {'weight': 2},
#   u'Schatz, Brian': {'weight': 0},
#   u'Schumer, Charles E.': {'weight': 5},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 1},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 3},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 6},
#   u'Toomey, Pat': {'weight': 2},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 7},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 4},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 2},
#   u'Wicker, Roger F.': {'weight': 2},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Booker, Cory A.': {u'Alexander, Lamar': {'weight': 0},
#   u'Ayotte, Kelly': {'weight': 2},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 1},
#   u'Begich, Mark': {'weight': 1},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 4},
#   u'Blunt, Roy': {'weight': 2},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 6},
#   u'Brown, Sherrod': {'weight': 3},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 2},
#   u'Carper, Thomas R.': {'weight': 2},
#   u'Casey, Robert P., Jr.': {'weight': 6},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 0},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 2},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 3},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 3},
#   u'Gillibrand, Kirsten E.': {'weight': 6},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 5},
#   u'Hatch, Orrin G.': {'weight': 0},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 0},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 3},
#   u'Klobuchar, Amy': {'weight': 5},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 4},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 1},
#   u'Markey, Edward J.': {'weight': 1},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 9},
#   u'Merkley, Jeff': {'weight': 2},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 0},
#   u'Murphy, Christopher S.': {'weight': 3},
#   u'Murray, Patty': {'weight': 3},
#   u'Nelson, Bill': {'weight': 2},
#   u'Paul, Rand': {'weight': 1},
#   u'Portman, Rob': {'weight': 0},
#   u'Pryor, Mark L.': {'weight': 1},
#   u'Reed, Jack': {'weight': 4},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 0},
#   u'Rubio, Marco': {'weight': 1},
#   u'Sanders, Bernard': {'weight': 3},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 3},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 1},
#   u'Shelby, Richard C.': {'weight': 0},
#   u'Stabenow, Debbie': {'weight': 1},
#   u'Tester, Jon': {'weight': 2},
#   u'Thune, John': {'weight': 1},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 0},
#   u'Warren, Elizabeth': {'weight': 2},
#   u'Whitehouse, Sheldon': {'weight': 2},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 1}},
#  u'Boozman, John': {u'Alexander, Lamar': {'weight': 2},
#   u'Ayotte, Kelly': {'weight': 4},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 5},
#   u'Baucus, Max': {'weight': 1},
#   u'Begich, Mark': {'weight': 4},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 2},
#   u'Blunt, Roy': {'weight': 7},
#   u'Booker, Cory A.': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 2},
#   u'Brown, Sherrod': {'weight': 5},
#   u'Burr, Richard': {'weight': 3},
#   u'Cantwell, Maria': {'weight': 0},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 3},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 1},
#   u'Coburn, Tom': {'weight': 7},
#   u'Cochran, Thad': {'weight': 2},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 1},
#   u'Cornyn, John': {'weight': 7},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 4},
#   u'Donnelly, Joe': {'weight': 2},
#   u'Durbin, Richard': {'weight': 1},
#   u'Enzi, Michael B.': {'weight': 4},
#   u'Feinstein, Dianne': {'weight': 0},
#   u'Fischer, Deb': {'weight': 3},
#   u'Flake, Jeff': {'weight': 2},
#   u'Franken, Al': {'weight': 2},
#   u'Gillibrand, Kirsten E.': {'weight': 0},
#   u'Graham, Lindsey': {'weight': 1},
#   u'Grassley, Chuck': {'weight': 2},
#   u'Hagan, Kay R.': {'weight': 2},
#   u'Harkin, Tom': {'weight': 2},
#   u'Hatch, Orrin G.': {'weight': 3},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 3},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 5},
#   u'Inhofe, James M.': {'weight': 7},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 4},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 3},
#   u'Klobuchar, Amy': {'weight': 3},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 1},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 2},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 2},
#   u'Markey, Edward J.': {'weight': 1},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 0},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 3},
#   u'Merkley, Jeff': {'weight': 0},
#   u'Mikulski, Barbara A.': {'weight': 0},
#   u'Moran, Jerry': {'weight': 4},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 1},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 5},
#   u'Portman, Rob': {'weight': 5},
#   u'Pryor, Mark L.': {'weight': 16},
#   u'Reed, Jack': {'weight': 0},
#   u'Reid, Harry': {'weight': 1},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 3},
#   u'Rockefeller, John D., IV': {'weight': 1},
#   u'Rubio, Marco': {'weight': 6},
#   u'Sanders, Bernard': {'weight': 2},
#   u'Schatz, Brian': {'weight': 0},
#   u'Schumer, Charles E.': {'weight': 0},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 2},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 0},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 7},
#   u'Toomey, Pat': {'weight': 1},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 10},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 2},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 0},
#   u'Wicker, Roger F.': {'weight': 4},
#   u'Wyden, Ron': {'weight': 3}},
#  u'Boxer, Barbara': {u'Alexander, Lamar': {'weight': 0},
#   u'Ayotte, Kelly': {'weight': 2},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 2},
#   u'Begich, Mark': {'weight': 3},
#   u'Bennet, Michael F.': {'weight': 1},
#   u'Blumenthal, Richard': {'weight': 5},
#   u'Blunt, Roy': {'weight': 3},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 0},
#   u'Brown, Sherrod': {'weight': 8},
#   u'Burr, Richard': {'weight': 2},
#   u'Cantwell, Maria': {'weight': 4},
#   u'Cardin, Benjamin L.': {'weight': 5},
#   u'Carper, Thomas R.': {'weight': 1},
#   u'Casey, Robert P., Jr.': {'weight': 8},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 4},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 0},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 12},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 19},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 5},
#   u'Gillibrand, Kirsten E.': {'weight': 5},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 7},
#   u'Hatch, Orrin G.': {'weight': 0},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 1},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 0},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 2},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 0},
#   u'Klobuchar, Amy': {'weight': 3},
#   u'Landrieu, Mary L.': {'weight': 2},
#   u'Lautenberg, Frank R.': {'weight': 9},
#   u'Leahy, Patrick J.': {'weight': 6},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 2},
#   u'Manchin, Joe, III': {'weight': 2},
#   u'Markey, Edward J.': {'weight': 5},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 9},
#   u'Merkley, Jeff': {'weight': 1},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 1},
#   u'Murray, Patty': {'weight': 6},
#   u'Nelson, Bill': {'weight': 4},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 2},
#   u'Pryor, Mark L.': {'weight': 1},
#   u'Reed, Jack': {'weight': 7},
#   u'Reid, Harry': {'weight': 9},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 2},
#   u'Rubio, Marco': {'weight': 0},
#   u'Sanders, Bernard': {'weight': 10},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 6},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 6},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 4},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 2},
#   u'Vitter, David': {'weight': 1},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 5},
#   u'Whitehouse, Sheldon': {'weight': 5},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 4}},
#  u'Brown, Sherrod': {u'Alexander, Lamar': {'weight': 0},
#   u'Ayotte, Kelly': {'weight': 3},
#   u'Baldwin, Tammy': {'weight': 3},
#   u'Barrasso, John': {'weight': 1},
#   u'Baucus, Max': {'weight': 2},
#   u'Begich, Mark': {'weight': 3},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 7},
#   u'Blunt, Roy': {'weight': 3},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 1},
#   u'Boxer, Barbara': {'weight': 4},
#   u'Burr, Richard': {'weight': 1},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 6},
#   u'Carper, Thomas R.': {'weight': 2},
#   u'Casey, Robert P., Jr.': {'weight': 11},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 2},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 1},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 13},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 3},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 9},
#   u'Gillibrand, Kirsten E.': {'weight': 4},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 2},
#   u'Hagan, Kay R.': {'weight': 1},
#   u'Harkin, Tom': {'weight': 15},
#   u'Hatch, Orrin G.': {'weight': 1},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 0},
#   u'Inhofe, James M.': {'weight': 1},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 3},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 3},
#   u'Leahy, Patrick J.': {'weight': 7},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 4},
#   u'Manchin, Joe, III': {'weight': 2},
#   u'Markey, Edward J.': {'weight': 3},
# ...
#   u'Rockefeller, John D., IV': {'weight': 1},
#   u'Rubio, Marco': {'weight': 1},
#   u'Sanders, Bernard': {'weight': 0},
#   u'Schatz, Brian': {'weight': 0},
#   u'Schumer, Charles E.': {'weight': 1},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 8},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 2},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 1},
#   u'Udall, Mark': {'weight': 1},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 2},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Warren, Elizabeth': {u'Alexander, Lamar': {'weight': 0},
#   u'Ayotte, Kelly': {'weight': 2},
#   u'Baldwin, Tammy': {'weight': 1},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 2},
#   u'Begich, Mark': {'weight': 2},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 10},
#   u'Blunt, Roy': {'weight': 2},
#   u'Booker, Cory A.': {'weight': 1},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 9},
#   u'Brown, Sherrod': {'weight': 8},
#   u'Burr, Richard': {'weight': 2},
#   u'Cantwell, Maria': {'weight': 4},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 2},
#   u'Casey, Robert P., Jr.': {'weight': 6},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 2},
#   u'Corker, Bob': {'weight': 1},
#   u'Cornyn, John': {'weight': 0},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 10},
#   u'Enzi, Michael B.': {'weight': 2},
#   u'Feinstein, Dianne': {'weight': 4},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 9},
#   u'Gillibrand, Kirsten E.': {'weight': 9},
#   u'Graham, Lindsey': {'weight': 1},
#   u'Grassley, Chuck': {'weight': 0},
#   u'Hagan, Kay R.': {'weight': 1},
#   u'Harkin, Tom': {'weight': 16},
#   u'Hatch, Orrin G.': {'weight': 0},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 1},
#   u'Heller, Dean': {'weight': 1},
#   u'Hirono, Mazie K.': {'weight': 0},
#   u'Hoeven, John': {'weight': 0},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 1},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 2},
#   u'Klobuchar, Amy': {'weight': 1},
#   u'Landrieu, Mary L.': {'weight': 4},
#   u'Lautenberg, Frank R.': {'weight': 6},
#   u'Leahy, Patrick J.': {'weight': 7},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 1},
#   u'Manchin, Joe, III': {'weight': 2},
#   u'Markey, Edward J.': {'weight': 8},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 0},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 6},
#   u'Merkley, Jeff': {'weight': 4},
#   u'Mikulski, Barbara A.': {'weight': 3},
#   u'Moran, Jerry': {'weight': 1},
#   u'Murkowski, Lisa': {'weight': 1},
#   u'Murphy, Christopher S.': {'weight': 1},
#   u'Murray, Patty': {'weight': 5},
#   u'Nelson, Bill': {'weight': 1},
#   u'Paul, Rand': {'weight': 1},
#   u'Portman, Rob': {'weight': 1},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 16},
#   u'Reid, Harry': {'weight': 1},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 3},
#   u'Rubio, Marco': {'weight': 2},
#   u'Sanders, Bernard': {'weight': 5},
#   u'Schatz, Brian': {'weight': 2},
#   u'Schumer, Charles E.': {'weight': 5},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 5},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 3},
#   u'Tester, Jon': {'weight': 4},
#   u'Thune, John': {'weight': 1},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 1},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Whitehouse, Sheldon': {'weight': 7},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 1}},
#  u'Whitehouse, Sheldon': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 3},
#   u'Baldwin, Tammy': {'weight': 3},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 3},
#   u'Begich, Mark': {'weight': 2},
#   u'Bennet, Michael F.': {'weight': 0},
#   u'Blumenthal, Richard': {'weight': 12},
#   u'Blunt, Roy': {'weight': 0},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 7},
#   u'Brown, Sherrod': {'weight': 11},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 2},
#   u'Cardin, Benjamin L.': {'weight': 6},
#   u'Carper, Thomas R.': {'weight': 3},
#   u'Casey, Robert P., Jr.': {'weight': 4},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 0},
#   u'Cochran, Thad': {'weight': 0},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 2},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 0},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 1},
#   u'Durbin, Richard': {'weight': 13},
#   u'Enzi, Michael B.': {'weight': 3},
#   u'Feinstein, Dianne': {'weight': 7},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 6},
#   u'Gillibrand, Kirsten E.': {'weight': 3},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 1},
#   u'Harkin, Tom': {'weight': 12},
#   u'Hatch, Orrin G.': {'weight': 2},
#   u'Heinrich, Martin': {'weight': 0},
#   u'Heitkamp, Heidi': {'weight': 1},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 0},
#   u'Inhofe, James M.': {'weight': 0},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 1},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 1},
#   u'Kaine, Tim': {'weight': 0},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 4},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 12},
#   u'Leahy, Patrick J.': {'weight': 13},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 5},
#   u'Manchin, Joe, III': {'weight': 1},
#   u'Markey, Edward J.': {'weight': 4},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 10},
#   u'Merkley, Jeff': {'weight': 3},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 0},
#   u'Murkowski, Lisa': {'weight': 2},
#   u'Murphy, Christopher S.': {'weight': 2},
#   u'Murray, Patty': {'weight': 2},
#   u'Nelson, Bill': {'weight': 4},
#   u'Paul, Rand': {'weight': 0},
#   u'Portman, Rob': {'weight': 3},
#   u'Pryor, Mark L.': {'weight': 2},
#   u'Reed, Jack': {'weight': 22},
#   u'Reid, Harry': {'weight': 4},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 6},
#   u'Rubio, Marco': {'weight': 1},
#   u'Sanders, Bernard': {'weight': 8},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 3},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 7},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 4},
#   u'Tester, Jon': {'weight': 2},
#   u'Thune, John': {'weight': 0},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 2},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 2},
#   u'Walsh, John E.': {'weight': 2},
#   u'Warner, Mark R.': {'weight': 2},
#   u'Warren, Elizabeth': {'weight': 4},
#   u'Wicker, Roger F.': {'weight': 0},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Wicker, Roger F.': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 4},
#   u'Baldwin, Tammy': {'weight': 0},
#   u'Barrasso, John': {'weight': 5},
#   u'Baucus, Max': {'weight': 2},
#   u'Begich, Mark': {'weight': 3},
#   u'Bennet, Michael F.': {'weight': 2},
#   u'Blumenthal, Richard': {'weight': 2},
#   u'Blunt, Roy': {'weight': 7},
#   u'Booker, Cory A.': {'weight': 1},
#   u'Boozman, John': {'weight': 4},
#   u'Boxer, Barbara': {'weight': 2},
#   u'Brown, Sherrod': {'weight': 7},
#   u'Burr, Richard': {'weight': 1},
#   u'Cantwell, Maria': {'weight': 0},
#   u'Cardin, Benjamin L.': {'weight': 3},
#   u'Carper, Thomas R.': {'weight': 0},
#   u'Casey, Robert P., Jr.': {'weight': 3},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 3},
#   u'Coburn, Tom': {'weight': 4},
#   u'Cochran, Thad': {'weight': 10},
#   u'Collins, Susan M.': {'weight': 0},
#   u'Coons, Christopher A.': {'weight': 0},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 9},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 0},
#   u'Cruz, Ted': {'weight': 3},
#   u'Donnelly, Joe': {'weight': 3},
#   u'Durbin, Richard': {'weight': 1},
#   u'Enzi, Michael B.': {'weight': 1},
#   u'Feinstein, Dianne': {'weight': 0},
#   u'Fischer, Deb': {'weight': 1},
#   u'Flake, Jeff': {'weight': 3},
#   u'Franken, Al': {'weight': 0},
#   u'Gillibrand, Kirsten E.': {'weight': 1},
#   u'Graham, Lindsey': {'weight': 1},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 2},
#   u'Harkin, Tom': {'weight': 4},
#   u'Hatch, Orrin G.': {'weight': 7},
#   u'Heinrich, Martin': {'weight': 1},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 1},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 5},
#   u'Inhofe, James M.': {'weight': 4},
#   u'Isakson, Johnny': {'weight': 1},
#   u'Johanns, Mike': {'weight': 2},
#   u'Johnson, Ron': {'weight': 1},
#   u'Johnson, Tim': {'weight': 0},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 4},
#   u'Landrieu, Mary L.': {'weight': 6},
#   u'Lautenberg, Frank R.': {'weight': 0},
#   u'Leahy, Patrick J.': {'weight': 1},
#   u'Lee, Mike': {'weight': 3},
#   u'Levin, Carl': {'weight': 0},
#   u'Manchin, Joe, III': {'weight': 5},
#   u'Markey, Edward J.': {'weight': 1},
#   u'McCain, John': {'weight': 1},
#   u'McCaskill, Claire': {'weight': 1},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 5},
#   u'Merkley, Jeff': {'weight': 0},
#   u'Mikulski, Barbara A.': {'weight': 0},
#   u'Moran, Jerry': {'weight': 3},
#   u'Murkowski, Lisa': {'weight': 2},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 0},
#   u'Nelson, Bill': {'weight': 2},
#   u'Paul, Rand': {'weight': 4},
#   u'Portman, Rob': {'weight': 4},
#   u'Pryor, Mark L.': {'weight': 3},
#   u'Reed, Jack': {'weight': 0},
#   u'Reid, Harry': {'weight': 0},
#   u'Risch, James E.': {'weight': 1},
#   u'Roberts, Pat': {'weight': 5},
#   u'Rockefeller, John D., IV': {'weight': 1},
#   u'Rubio, Marco': {'weight': 8},
#   u'Sanders, Bernard': {'weight': 1},
#   u'Schatz, Brian': {'weight': 1},
#   u'Schumer, Charles E.': {'weight': 2},
#   u'Scott, Tim': {'weight': 1},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 4},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 1},
#   u'Tester, Jon': {'weight': 3},
#   u'Thune, John': {'weight': 3},
#   u'Toomey, Pat': {'weight': 3},
#   u'Udall, Mark': {'weight': 0},
#   u'Udall, Tom': {'weight': 0},
#   u'Vitter, David': {'weight': 8},
#   u'Walsh, John E.': {'weight': 0},
#   u'Warner, Mark R.': {'weight': 3},
#   u'Warren, Elizabeth': {'weight': 0},
#   u'Whitehouse, Sheldon': {'weight': 0},
#   u'Wyden, Ron': {'weight': 2}},
#  u'Wyden, Ron': {u'Alexander, Lamar': {'weight': 1},
#   u'Ayotte, Kelly': {'weight': 2},
#   u'Baldwin, Tammy': {'weight': 1},
#   u'Barrasso, John': {'weight': 0},
#   u'Baucus, Max': {'weight': 6},
#   u'Begich, Mark': {'weight': 2},
#   u'Bennet, Michael F.': {'weight': 1},
#   u'Blumenthal, Richard': {'weight': 6},
#   u'Blunt, Roy': {'weight': 2},
#   u'Booker, Cory A.': {'weight': 2},
#   u'Boozman, John': {'weight': 0},
#   u'Boxer, Barbara': {'weight': 8},
#   u'Brown, Sherrod': {'weight': 4},
#   u'Burr, Richard': {'weight': 0},
#   u'Cantwell, Maria': {'weight': 3},
#   u'Cardin, Benjamin L.': {'weight': 2},
#   u'Carper, Thomas R.': {'weight': 0},
#   u'Casey, Robert P., Jr.': {'weight': 3},
#   u'Chambliss, Saxby': {'weight': 0},
#   u'Chiesa, Jeff': {'weight': 0},
#   u'Coats, Daniel': {'weight': 0},
#   u'Coburn, Tom': {'weight': 1},
#   u'Cochran, Thad': {'weight': 1},
#   u'Collins, Susan M.': {'weight': 2},
#   u'Coons, Christopher A.': {'weight': 1},
#   u'Corker, Bob': {'weight': 0},
#   u'Cornyn, John': {'weight': 2},
#   u'Cowan, William M.': {'weight': 0},
#   u'Crapo, Mike': {'weight': 1},
#   u'Cruz, Ted': {'weight': 0},
#   u'Donnelly, Joe': {'weight': 0},
#   u'Durbin, Richard': {'weight': 2},
#   u'Enzi, Michael B.': {'weight': 0},
#   u'Feinstein, Dianne': {'weight': 5},
#   u'Fischer, Deb': {'weight': 0},
#   u'Flake, Jeff': {'weight': 0},
#   u'Franken, Al': {'weight': 6},
#   u'Gillibrand, Kirsten E.': {'weight': 5},
#   u'Graham, Lindsey': {'weight': 0},
#   u'Grassley, Chuck': {'weight': 1},
#   u'Hagan, Kay R.': {'weight': 0},
#   u'Harkin, Tom': {'weight': 5},
#   u'Hatch, Orrin G.': {'weight': 2},
#   u'Heinrich, Martin': {'weight': 2},
#   u'Heitkamp, Heidi': {'weight': 0},
#   u'Heller, Dean': {'weight': 0},
#   u'Hirono, Mazie K.': {'weight': 1},
#   u'Hoeven, John': {'weight': 1},
#   u'Inhofe, James M.': {'weight': 1},
#   u'Isakson, Johnny': {'weight': 0},
#   u'Johanns, Mike': {'weight': 0},
#   u'Johnson, Ron': {'weight': 0},
#   u'Johnson, Tim': {'weight': 1},
#   u'Kaine, Tim': {'weight': 1},
#   u'Kerry, John F.': {'weight': 0},
#   u'King, Angus S., Jr.': {'weight': 0},
#   u'Kirk, Mark Steven': {'weight': 1},
#   u'Klobuchar, Amy': {'weight': 1},
#   u'Landrieu, Mary L.': {'weight': 1},
#   u'Lautenberg, Frank R.': {'weight': 4},
#   u'Leahy, Patrick J.': {'weight': 6},
#   u'Lee, Mike': {'weight': 0},
#   u'Levin, Carl': {'weight': 1},
#   u'Manchin, Joe, III': {'weight': 1},
#   u'Markey, Edward J.': {'weight': 3},
#   u'McCain, John': {'weight': 0},
#   u'McCaskill, Claire': {'weight': 0},
#   u'McConnell, Mitch': {'weight': 0},
#   u'Menendez, Robert': {'weight': 6},
#   u'Merkley, Jeff': {'weight': 7},
#   u'Mikulski, Barbara A.': {'weight': 2},
#   u'Moran, Jerry': {'weight': 1},
#   u'Murkowski, Lisa': {'weight': 4},
#   u'Murphy, Christopher S.': {'weight': 0},
#   u'Murray, Patty': {'weight': 3},
#   u'Nelson, Bill': {'weight': 2},
#   u'Paul, Rand': {'weight': 1},
#   u'Portman, Rob': {'weight': 0},
#   u'Pryor, Mark L.': {'weight': 5},
#   u'Reed, Jack': {'weight': 3},
#   u'Reid, Harry': {'weight': 4},
#   u'Risch, James E.': {'weight': 0},
#   u'Roberts, Pat': {'weight': 0},
#   u'Rockefeller, John D., IV': {'weight': 3},
#   u'Rubio, Marco': {'weight': 0},
#   u'Sanders, Bernard': {'weight': 5},
#   u'Schatz, Brian': {'weight': 3},
#   u'Schumer, Charles E.': {'weight': 3},
#   u'Scott, Tim': {'weight': 0},
#   u'Sessions, Jeff': {'weight': 0},
#   u'Shaheen, Jeanne': {'weight': 3},
#   u'Shelby, Richard C.': {'weight': 1},
#   u'Stabenow, Debbie': {'weight': 3},
#   u'Tester, Jon': {'weight': 5},
#   u'Thune, John': {'weight': 2},
#   u'Toomey, Pat': {'weight': 0},
#   u'Udall, Mark': {'weight': 2},
#   u'Udall, Tom': {'weight': 1},
#   u'Vitter, David': {'weight': 0},
#   u'Walsh, John E.': {'weight': 2},
#   u'Warner, Mark R.': {'weight': 1},
#   u'Warren, Elizabeth': {'weight': 1},
#   u'Whitehouse, Sheldon': {'weight': 0},
#   u'Wicker, Roger F.': {'weight': 0}}}

# %%
"""
Function
--------
bill_graph

Turn the bill graph data into a NetworkX Digraph

Parameters
----------
data : list of dicts
    The data returned from get_all_bills

Returns
-------
graph : A NetworkX DiGraph, with the following properties
    * Each node is a senator. For a label, use the 'name' field 
      from the 'sponsor' and 'cosponsors' dict items
    * Each edge from A to B is assigned a weight equal to how many 
      bills are sponsored by B and co-sponsored by A
"""
#Your code here
def bill_graph(data):
    # get a list of senators
    senators = set()
    for b in data:
        senators.add(b['sponsor']['name'])
        for s in b['cosponsors']:
            senators.add(s['name'])
    
    # build weight hash
    weight = {s1: {s2: 0 for s2 in senators if s2 != s1} for s1 in senators}
    for b in data:
        for co in b['cosponsors']:
            weight[co['name']][b['sponsor']['name']] += 1
        
    # build graph
    g = nx.DiGraph()
    for s in senators:
        g.add_node(s)
    
    for s1 in weight.keys():
        for s2 in weight[s1].keys():
            g.add_edge(s1, s2, {'weight': weight[s1][s2]})
    return g

# %%
bills = bill_graph(bill_list)

# %%
bills['Johnson, Tim']
# Out:
# {u'Alexander, Lamar': {'weight': 0},
#  u'Ayotte, Kelly': {'weight': 2},
#  u'Baldwin, Tammy': {'weight': 0},
#  u'Barrasso, John': {'weight': 1},
#  u'Baucus, Max': {'weight': 5},
#  u'Begich, Mark': {'weight': 4},
#  u'Bennet, Michael F.': {'weight': 1},
#  u'Blumenthal, Richard': {'weight': 1},
#  u'Blunt, Roy': {'weight': 2},
#  u'Booker, Cory A.': {'weight': 0},
#  u'Boozman, John': {'weight': 0},
#  u'Boxer, Barbara': {'weight': 4},
#  u'Brown, Sherrod': {'weight': 7},
#  u'Burr, Richard': {'weight': 0},
#  u'Cantwell, Maria': {'weight': 4},
#  u'Cardin, Benjamin L.': {'weight': 2},
#  u'Carper, Thomas R.': {'weight': 0},
#  u'Casey, Robert P., Jr.': {'weight': 4},
#  u'Chambliss, Saxby': {'weight': 0},
#  u'Chiesa, Jeff': {'weight': 0},
#  u'Coats, Daniel': {'weight': 0},
#  u'Coburn, Tom': {'weight': 0},
#  u'Cochran, Thad': {'weight': 1},
#  u'Collins, Susan M.': {'weight': 1},
#  u'Coons, Christopher A.': {'weight': 1},
#  u'Corker, Bob': {'weight': 0},
#  u'Cornyn, John': {'weight': 0},
#  u'Cowan, William M.': {'weight': 0},
#  u'Crapo, Mike': {'weight': 0},
#  u'Cruz, Ted': {'weight': 0},
#  u'Donnelly, Joe': {'weight': 0},
#  u'Durbin, Richard': {'weight': 1},
#  u'Enzi, Michael B.': {'weight': 5},
#  u'Feinstein, Dianne': {'weight': 1},
#  u'Fischer, Deb': {'weight': 0},
#  u'Flake, Jeff': {'weight': 0},
#  u'Franken, Al': {'weight': 7},
#  u'Gillibrand, Kirsten E.': {'weight': 2},
#  u'Graham, Lindsey': {'weight': 0},
#  u'Grassley, Chuck': {'weight': 1},
#  u'Hagan, Kay R.': {'weight': 3},
#  u'Harkin, Tom': {'weight': 10},
#  u'Hatch, Orrin G.': {'weight': 0},
#  u'Heinrich, Martin': {'weight': 0},
#  u'Heitkamp, Heidi': {'weight': 1},
#  u'Heller, Dean': {'weight': 1},
#  u'Hirono, Mazie K.': {'weight': 2},
#  u'Hoeven, John': {'weight': 2},
#  u'Inhofe, James M.': {'weight': 1},
#  u'Isakson, Johnny': {'weight': 0},
#  u'Johanns, Mike': {'weight': 0},
#  u'Johnson, Ron': {'weight': 0},
#  u'Kaine, Tim': {'weight': 0},
#  u'Kerry, John F.': {'weight': 0},
#  u'King, Angus S., Jr.': {'weight': 0},
#  u'Kirk, Mark Steven': {'weight': 1},
#  u'Klobuchar, Amy': {'weight': 4},
#  u'Landrieu, Mary L.': {'weight': 2},
#  u'Lautenberg, Frank R.': {'weight': 2},
#  u'Leahy, Patrick J.': {'weight': 2},
#  u'Lee, Mike': {'weight': 0},
#  u'Levin, Carl': {'weight': 1},
#  u'Manchin, Joe, III': {'weight': 2},
#  u'Markey, Edward J.': {'weight': 0},
#  u'McCain, John': {'weight': 0},
#  u'McCaskill, Claire': {'weight': 0},
#  u'McConnell, Mitch': {'weight': 0},
#  u'Menendez, Robert': {'weight': 2},
#  u'Merkley, Jeff': {'weight': 1},
#  u'Mikulski, Barbara A.': {'weight': 1},
#  u'Moran, Jerry': {'weight': 2},
#  u'Murkowski, Lisa': {'weight': 1},
#  u'Murphy, Christopher S.': {'weight': 0},
#  u'Murray, Patty': {'weight': 2},
#  u'Nelson, Bill': {'weight': 1},
#  u'Paul, Rand': {'weight': 0},
#  u'Portman, Rob': {'weight': 2},
#  u'Pryor, Mark L.': {'weight': 4},
#  u'Reed, Jack': {'weight': 5},
#  u'Reid, Harry': {'weight': 2},
#  u'Risch, James E.': {'weight': 0},
#  u'Roberts, Pat': {'weight': 1},
#  u'Rockefeller, John D., IV': {'weight': 2},
#  u'Rubio, Marco': {'weight': 0},
#  u'Sanders, Bernard': {'weight': 2},
#  u'Schatz, Brian': {'weight': 0},
#  u'Schumer, Charles E.': {'weight': 3},
#  u'Scott, Tim': {'weight': 0},
#  u'Sessions, Jeff': {'weight': 0},
#  u'Shaheen, Jeanne': {'weight': 2},
#  u'Shelby, Richard C.': {'weight': 1},
#  u'Stabenow, Debbie': {'weight': 0},
#  u'Tester, Jon': {'weight': 11},
#  u'Thune, John': {'weight': 3},
#  u'Toomey, Pat': {'weight': 0},
#  u'Udall, Mark': {'weight': 0},
#  u'Udall, Tom': {'weight': 1},
#  u'Vitter, David': {'weight': 1},
#  u'Walsh, John E.': {'weight': 0},
#  u'Warner, Mark R.': {'weight': 2},
#  u'Warren, Elizabeth': {'weight': 1},
#  u'Whitehouse, Sheldon': {'weight': 4},
#  u'Wicker, Roger F.': {'weight': 1},
#  u'Wyden, Ron': {'weight': 5}}

# %% [markdown]
# ### Problem 9
#
# Using `nx.pagerank_numpy`, compute the PageRank score for each senator in this graph. Visualize the results. Determine the 5 Senators with the highest
# PageRank scores. How effective is this approach at identifying leaders? How does the PageRank rating compare to the degree of each node?
#
# Note: you can read about individual Senators by searching for them on the [govtrack website](https://www.govtrack.us/).

# %%
d = {'a': 2, 'b': -1, 'c': 5}
# d_sorted = sorted(d.iteritems(), key=operator.itemgetter(1))
d_sorted = sorted(d.iteritems(), key=lambda item: item[1])

d_sorted
# Out:
# [('b', -1), ('a', 2), ('c', 5)]

# %%
#Your code here
page_rank = nx.pagerank_numpy(bills)
# Out:
# 105

# %%
page_rank_sort = sorted(page_rank.iteritems(), key=operator.itemgetter(1))

# %%
print "highest ranking senators:"
for s in page_rank_sort[-5:]:
    print s
# Out:
# highest ranking senators:
# (u'Leahy, Patrick J.', 0.022087354743715263)
# (u'Boxer, Barbara', 0.022546214288525903)
# (u'Menendez, Robert', 0.026849989830274434)
# (u'Harkin, Tom', 0.028110609673966808)
# (u'Brown, Sherrod', 0.028198062836445905)

# %%
#Your code here

# %% [markdown]
# *Your discussion here*

# %% [markdown]
# ### Interactive Visualization
#
# Producing a good node link layout is not quite so simple. Nevertheless, we will give it a try.
#
# We will use [Gephi](https://gephi.org/) for interactive graph visualization. Gephi supports a wide variety of graph file formats, and NetworkX exports to several of them. We'll use the Graph Exchange XML Format (GEXF).

# %%
nx.write_gexf(votes, 'votes2.gexf')

# %% [markdown]
# ### Problem 10: Analysis with Gephi
#
# Download and install [Gephi](https://gephi.org/). See the [lab](http://goo.gl/SzHioP) for a brief introduction. Load the exported votes file. Try to produce a layout that clearly separates Democrats from Republicans (hint: filter on edge weight and re-layout once you filtered). Run PageRank and some other statistics and try encoding them with node color and node size. Run the "Modularity" statistic and encode the results in color.
#
# Include a screenshot of your "best" visualization and embed the image here with `IPython.display.Image`. Make sure to include this image in your submission.
#
# Explain your observations. Is the network visualization very helpful? Try to visualize your LinkedIn network (see the lab) or the one provided in the lab. Which dataset is more suitable for visualization and why is there a difference?

# %%
from IPython.display import Image

path = 'name_of_your_screenshot'
Image(path)

# %% [markdown]
# *Your answer here*

# %% [markdown]
# ### How to Submit
#
# To submit your homework, create a folder named lastname_firstinitial_hw5 and place this notebook file in the folder. Double check that this file is still called HW5.ipynb, and that it contains your solutions. Also include any Gephi screenshots. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work.

# %% [markdown]
# ---
# *css tweaks in this cell*
# <style>
# div.text_cell_render {
#     line-height: 150%;
#     font-size: 110%;
#     width: 800px;
#     margin-left:50px;
#     margin-right:auto;
#     }
# </style>
